# %%
# Запросите у пользователя год рождения и текущий год. Вычислите и выведите его возраст

birth_year = int(input("Введите год рождения: "))
current_year = int(input("Введите текущий год: "))
age = current_year - birth_year
print("Вам", age, "лет")
# Out:
# Введите год рождения: 2000
# Введите текущий год: 2025
# Вам 25 лет

# %%
# Пользователь вводит сумму в рублях и курс доллара. Программа выводит эквивалент в долларах
# 5000 рублей по курсу 75 = 66.67 долларов

rubles = float(input("Введите сумму в рублях: "))
exchange_rate = float(input("Введите курс доллара: "))

dollars = rubles / exchange_rate

print(rubles, "рублей по курсу", exchange_rate, "=", round(dollars, 2), "долларов")
# Out:
# Введите сумму в рублях: 5000
# Введите курс доллара: 75
# 5000.0 рублей по курсу 75.0 = 66.67 долларов

# %%
# Пользователь вводит сумму денег.
# Программа вычисляет, сколько это полных тысяч, сотен, десятков и единиц.

money = int(input("Введите сумму денег: "))

thousands = money // 1000
hundreds = (money % 1000) // 100
tens = (money % 100) // 10
units = money % 10

print(money, "->", thousands, "тысячи,", hundreds, "сотен,", tens, "десятков,", units, "единиц")
# Out:
# Введите сумму денег: 3875
# 3875 -> 3 тысячи, 8 сотен, 7 десятков, 5 единиц

# %%
# Создание форматированных логов с разделителями
print("=== ИСПОЛЬЗОВАНИЕ + и * В ЛОГАХ ===")

# Создание визуальных разделителей
separator = "=" * 50
subseparator = "-" * 30

user = "Alice"
action = "login"
status = "SUCCESS"
timestamp = "10:30:15"

# Склеивание лог-сообщения
log_line = timestamp + " > " + user + " | " + action + " | " + status
log_block = separator + "\n" + log_line + "\n" + subseparator

print(log_block)
print("Повторение для красоты: " + "★ " * 5)
print(separator)
# Out:
# === ИСПОЛЬЗОВАНИЕ + и * В ЛОГАХ ===
# ==================================================
# 10:30:15 > Alice | login | SUCCESS
# ------------------------------
# Повторение для красоты: ★ ★ ★ ★ ★
# ==================================================

# %%
print("=== USER INFORMATION ===")

main_separator = "=" * 35
sub_separator = "-" * 35

user1 = "Andrew"
action1 = "login"
status1 = "SUCCESS"
date = "15 Sep 2025"

user2 = "User 2"

log_user1 = date + " >> User: " + user1 + "\n" + date + " >> Action: " + action1 + "\n" + date + " >> Status: " + status1

log_block = main_separator + "\n" + "User 1" + "\n" + sub_separator + "\n" + log_user1 + "\n" + sub_separator + "\n" + user2 + "\n" + main_separator

print(log_block)
# Out:
# === USER INFORMATION ===
# ===================================
# User 1
# -----------------------------------
# 15 Sep 2025 >> User: Andrew
# 15 Sep 2025 >> Action: login
# 15 Sep 2025 >> Status: SUCCESS
# -----------------------------------
# User 2
# ===================================

# %%
print("=== ФИНАНСОВЫЙ ОТЧЕТ ===")

company = "ООО 'Рога и копыта'"
quarter = 4
year = 2023
revenue = 15000000.5678
expenses = 9000000.1234
profit = revenue - expenses
profit_margin = (profit / revenue) * 100

report = f"""
{company.upper()}
ОТЧЕТ ЗА {quarter}-Й КВАРТАЛ {year} ГОДА
--------------------------------------------------
Выручка:          {revenue:15,.2f} ₽
Расходы:          {expenses:15,.2f} ₽
Прибыль:          {profit:15,.2f} ₽
Рентабельность:   {profit_margin:15.1f} %
"""

print(report)
# Out:
# === ФИНАНСОВЫЙ ОТЧЕТ ===
#
# ООО 'РОГА И КОПЫТА'
# ОТЧЕТ ЗА 4-Й КВАРТАЛ 2023 ГОДА
# --------------------------------------------------
# Выручка:            15,000,000.57 ₽
# Расходы:             9,000,000.12 ₽
# Прибыль:             6,000,000.44 ₽
# Рентабельность:              40.0 %

# %%
print("=== ПРОГРЕСС ВЫПОЛНЕНИЯ ЗАДАЧ ===")

total_tasks = 150
completed_tasks = 87
progress = (completed_tasks / total_tasks) * 100

bar_length = 30
filled_length = int(bar_length * completed_tasks // total_tasks)
bar = '█' * filled_length + '░' * (bar_length - filled_length)

report = f"""
ВЫПОЛНЕНИЕ ЗАДАЧ:
[{bar}] {progress:.1f}%
Завершено: {completed_tasks}/{total_tasks} задач
"""

print(report)
# Out:
# === ПРОГРЕСС ВЫПОЛНЕНИЯ ЗАДАЧ ===
#
# ВЫПОЛНЕНИЕ ЗАДАЧ:
# [█████████████████░░░░░░░░░░░░░] 58.0%
# Завершено: 87/150 задач

# %%
# Работа с карточкой пользователя
print("=== КАРТОЧКА ПОЛЬЗОВАТЕЛЯ ===")

user_card = "USR-2024-0015-ALICE-PRO-DATA_SCIENCE"

# Извлекаем информацию через срезы
user_id = user_card[:13]           # USR-2024-0015
user_year = user_card[4:8]          # 2024
user_number = user_card[9:13]       # 0015
username = user_card[14:19]         # ALICE
user_level = user_card[-16:-13]       # PRO
specialization = user_card[-12:]     # DATA_SCIENCE

# Форматируем красивый вывод
profile = f"""
ПРОФИЛЬ ПОЛЬЗОВАТЕЛЯ
{'-'*30}
ID: {user_id}
Год регистрации: {user_year}
Номер: {user_number}
Имя: {username.title()}
Уровень: {user_level}
Специализация: {specialization.replace('_', ' ').title()}
"""

print(profile)
# Out:
# === КАРТОЧКА ПОЛЬЗОВАТЕЛЯ ===
#
# ПРОФИЛЬ ПОЛЬЗОВАТЕЛЯ
# ------------------------------
# ID: USR-2024-0015
# Год регистрации: 2024
# Номер: 0015
# Имя: Alice
# Уровень: PRO
# Специализация: Data Science

# %%
print("=== АНАЛИЗ БЛОКЧЕЙН-АДРЕСА ===")

wallet_address = "0x1a2b3c4d5e6f7890abc123def456ghi789jkl012mno345pqr678stu901vwx234yz"

# Извлекаем критически важные части адреса
protocol = wallet_address[:2]           # первые 2 символа
checksum = wallet_address[2:10]         # от 2 до 10 символа
user_identifier = wallet_address[10:20] # от 10 до 20
network_marker = wallet_address[-8:]    # последние 8 символов

print(f"Протокол: {protocol}")
print(f"Контрольная сумма: {checksum}")
print(f"ID пользователя: {user_identifier}")
print(f"Маркер сети: {network_marker}")

# Секретный код через каждый 4-й символ
secret_pattern = wallet_address[::4]
print(f"Секретный паттерн: {secret_pattern}")
# Out:
# === АНАЛИЗ БЛОКЧЕЙН-АДРЕСА ===
# Протокол: 0x
# Контрольная сумма: 1a2b3c4d
# ID пользователя: 5e6f7890ab
# Маркер сети: vwx234yz
# Секретный паттерн: 02469cd5ij1op7uv3

# %%
print("=== ГЕНЕРАТОР УМНЫХ ПАРОЛЕЙ ===")

base_string = "AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz0123456789!@#$%^&*"

# Генерируем пароли разной сложности через срезы
simple_password = base_string[::8]     # Каждый 8-й символ
medium_password = base_string[5:40:3]  # С 5-го по 40-й, каждый 3-й
complex_password = base_string[10::2] + base_string[:30:5]  # Комбинация: c 10го каждый второй + с 0 по 30, каждый 5ый

print(f"Уровни паролей:")
print(f"Простой: {simple_password}")
print(f"Средний: {medium_password}")
print(f"Сложный: {complex_password}")
# Out:
# === ГЕНЕРАТОР УМНЫХ ПАРОЛЕЙ ===
# Уровни паролей:
# Простой: AEIMQUY4#
# Средний: cEfHiKlNoQrT
# Сложный: FGHIJKLMNOPQRSTUVWXYZ02468!#%&AcFhKm
