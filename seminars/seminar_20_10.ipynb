# %%
# Задача 1: Форматирование ФИО
full_name = "иванов иван иванович"
# Ожидаемый вывод: "Иванов И.И."

parts = full_name.split()
formatted_name = parts[0].title() + " " + parts[1][0].upper() + "." + parts[2][0].upper() + "."

print(formatted_name)
# Out:
# Иванов И.И.

# %%
# Задача 2: Анализ пароля
password = "Password123"
# Проверьте:
# - длину не менее 8 символов
# - содержит цифры
# - содержит заглавные буквы

length_ok = len(password) >= 8
has_digits = any(char.isdigit() for char in password)
has_uppercase = any(char.isupper() for char in password)

print(f"Длина не менее 8 символов: {length_ok}")
print(f"Содержит цифры: {has_digits}")
print(f"Содержит заглавные буквы: {has_uppercase}")
print(f"Пароль соответствует требованиям: {length_ok and has_digits and has_uppercase}")
# Out:
# Длина не менее 8 символов: True
# Содержит цифры: True
# Содержит заглавные буквы: True
# Пароль соответствует требованиям: True

# %%
# Задача 3: Обработка пути к файлу
path = "/home/user/documents/report.pdf"
# Извлеките имя файла без расширения
# Ожидаемый вывод: "report"

filename_with_ext = path.split("/")[-1]

filename = filename_with_ext.split(".")[0]

print(filename)
# Out:
# report

# %%
# Задача 4: Поиск телефона
text = "Звоните по номеру +7-123-456-78-90 или +7-987-654-32-10"
# Найдите все номера телефонов (содержат +7-)
phones = []
parts = text.split()

for part in parts:
    if part.startswith("+7-"):
        phones.append(part)

# Убираем возможные знаки препинания в конце
clean_phones = [phone.rstrip('.,!?;') for phone in phones]

print("Найденные номера:")
for phone in clean_phones:
    print(phone)
# Out:
# Найденные номера:
# +7-123-456-78-90
# +7-987-654-32-10

# %%
# Задача 5: Нормализация текста
text = "   ЭТОТ ТЕКСТ ПИСАЛИ КАПСОМ    "
# Приведите к нормальному виду: первая буква заглавная, остальные маленькие
# Ожидаемый вывод: "Этот текст писали капсом"

text = "   ЭТОТ ТЕКСТ ПИСАЛИ КАПСОМ    "

clean_text = text.strip()
lower_text = clean_text.lower()
normalized_text = lower_text.capitalize()

print(normalized_text)
# Out:
# Этот текст писали капсом

# %%
# Задача 6: Подсчет слов
sentence = "Быстрый рыжий лис прыгает через ленивую собаку"
# Посчитайте количество слов в предложении

words = sentence.split()
word_count = len(words)

print(f"Количество слов в предложении: {word_count}")
print(f"Слова: {words}")
# Out:
# Количество слов в предложении: 7
# Слова: ['Быстрый', 'рыжий', 'лис', 'прыгает', 'через', 'ленивую', 'собаку']

# %%
# Задача 7: Замена даты
text = "Встречаемся 2023-12-31 в 20:00"
# Замените формат даты на 31.12.2023

parts = text.split()

for i, part in enumerate(parts):
    if '-' in part and part.count('-') == 2:
        year, month, day = part.split('-')
        new_date = f"{day}.{month}.{year}"
        parts[i] = new_date

new_text = ' '.join(parts)

print(new_text)
# Out:
# Встречаемся 31.12.2023 в 20:00

# %%
# Задача 8: Валидация имени файла
filename = "my_document.backup.pdf"
# Проверьте, является ли файл PDF-документом

filename = "my_document.backup.pdf"

is_pdf = filename.endswith('.pdf')

print(f"Имя файла: {filename}")
print(f"Это PDF-документ: {is_pdf}")
# Out:
# Имя файла: my_document.backup.pdf
# Это PDF-документ: True

# %%
# Задача 9: Разбор URL
url = "https://example.com/category/product.html"
# Извлеките домен и имя страницы

path_part = url.split('://', 1)[1] if '://' in url else url

parts = path_part.split('/')

domain = parts[0]

page_name = parts[-1]

print(f"URL: {url}")
print(f"Домен: {domain}")
print(f"Имя страницы: {page_name}")
# Out:
# URL: https://example.com/category/product.html
# Домен: example.com
# Имя страницы: product.html

# %%
# Задача 10: Генератор логина
full_name = "Maria Ivanova"
# Создайте логин в формате: m_ivanova

parts = full_name.split()
login = parts[0][0].lower() + "_" + parts[1].lower()

print(f"Полное имя: {full_name}")
print(f"Логин: {login}")
# Out:
# Полное имя: Maria Ivanova
# Логин: m_ivanova
